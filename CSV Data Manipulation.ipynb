# %%
import pandas as pd
twitterinfo = pd.read_csv(r'chinasfaultcleaner.csv')
twitterinfo
# Out:
#                 date        username  replies  retweets  favorites  \
# 0     7/7/2020 12:40       waswa_jnr        0         0          4
# 1      7/7/2020 8:36     Sofiesweet1        0         0          0
# 2      7/7/2020 6:15      akuu_lunya        0         0          0
# 3      7/7/2020 4:14   locco_veteran        0         0          0
# 4    6/24/2020 21:49     PastorJeebs        0         0          0
# ..               ...             ...      ...       ...        ...
# 100   7/27/2013 9:22      wpcommaven        0         0          0
# 101  5/22/2013 22:34  JanaCernavskis        0         0          0
# 102  10/17/2012 2:34    activist_hat        0         0          0
# 103  3/26/2012 23:21      haanapopyk        1         0          0
# 104   1/17/2012 2:11  teresamccarthy        0         0          0
#
#                              hashtags  \
# 0      #ItsChinasFault #JoanChallenge
# 1                   # #itschinasfault
# 2                     #itsChinasfault
# ...

# %%
twitterinfo.isnull
# Out:
# <bound method DataFrame.isnull of                 date        username  replies  retweets  favorites  \
# 0     7/7/2020 12:40       waswa_jnr        0         0          4
# 1      7/7/2020 8:36     Sofiesweet1        0         0          0
# 2      7/7/2020 6:15      akuu_lunya        0         0          0
# 3      7/7/2020 4:14   locco_veteran        0         0          0
# 4    6/24/2020 21:49     PastorJeebs        0         0          0
# ..               ...             ...      ...       ...        ...
# 100   7/27/2013 9:22      wpcommaven        0         0          0
# 101  5/22/2013 22:34  JanaCernavskis        0         0          0
# 102  10/17/2012 2:34    activist_hat        0         0          0
# 103  3/26/2012 23:21      haanapopyk        1         0          0
# 104   1/17/2012 2:11  teresamccarthy        0         0          0
#
#                              hashtags  \
# 0      #ItsChinasFault #JoanChallenge
# 1                   # #itschinasfault
# ...

# %%
#to display one column only
twitterinfo['username']
# Out:
# 0           waswa_jnr
# 1         Sofiesweet1
# 2          akuu_lunya
# 3       locco_veteran
# 4         PastorJeebs
#             ...
# 100        wpcommaven
# 101    JanaCernavskis
# 102      activist_hat
# 103        haanapopyk
# 104    teresamccarthy
# Name: username, Length: 105, dtype: object

# %%
#displaying rows
twitterinfo[0:60]
# Out:
#                date         username  replies  retweets  favorites  \
# 0    7/7/2020 12:40        waswa_jnr        0         0          4
# 1     7/7/2020 8:36      Sofiesweet1        0         0          0
# 2     7/7/2020 6:15       akuu_lunya        0         0          0
# 3     7/7/2020 4:14    locco_veteran        0         0          0
# 4   6/24/2020 21:49      PastorJeebs        0         0          0
# 5    6/21/2020 0:20      MartiniDude        1         0          0
# 6    6/12/2020 3:30   NOSLEEPATALL69        0         0          0
# 7   5/28/2020 20:47   SirLanceisback        0         0          3
# 8   5/26/2020 22:19      MartiniDude        0         1          0
# 9   5/21/2020 17:28   SirLanceisback        1         0          2
# 10  5/21/2020 15:49   SirLanceisback        0         0          2
# 11   5/21/2020 2:27  Blondiemcblond1        0         0          0
# 12   5/20/2020 3:30   TheDailyPoint1        0         0          0
# ...

# %%
#selecting multple columns
newdata= twitterinfo[['username','hashtags','text']]
newdata
# Out:
#            username                          hashtags  \
# 0         waswa_jnr    #ItsChinasFault #JoanChallenge
# 1       Sofiesweet1                 # #itschinasfault
# 2        akuu_lunya                   #itsChinasfault
# 3     locco_veteran                   #itschinasfault
# 4       PastorJeebs                   #ItsChinasFault
# ..              ...                               ...
# 100      wpcommaven             #itsChinasfault #post
# 101  JanaCernavskis  #twohoursofsleep #itschinasfault
# 102    activist_hat     #Mitt #debate #itschinasfault
# 103      haanapopyk                   #itschinasfault
# 104  teresamccarthy         #scdebate #itschinasfault
#
#                                                   text
# 0    "Mashakos" Mutahi Kagwe #ItsChinasFault George...
# 1    M.S corona has ruined many peoples lives all b...
# 2    China treats us abnormally just because our ge...
# 3    Everything fake, situation faking see what we ...
# ...

# %%
#to select serveral columns and specified number of rows
specialdata= twitterinfo.loc[0:60,['username','hashtags','text']]
specialdata
# Out:
#            username                                           hashtags  \
# 0         waswa_jnr                     #ItsChinasFault #JoanChallenge
# 1       Sofiesweet1                                  # #itschinasfault
# 2        akuu_lunya                                    #itsChinasfault
# 3     locco_veteran                                    #itschinasfault
# 4       PastorJeebs                                    #ItsChinasFault
# ..              ...                                                ...
# 56   Edward84719132                                    #itschinasfault
# 57  AdamPhillips727  #MSMNeedsToSeeThis #ItsChinasFault #CCPcoronav...
# 58        CHag4life  #ItsChinasFAULT #ChineseVirus #ChineseWuhanVir...
# 59           cdsdrs                                    #itschinasfault
# 60  AdamPhillips727  #MSMNeedsToSeeThis #ItsChinasFault #CCPcoronav...
#
#                                                  text
# 0   "Mashakos" Mutahi Kagwe #ItsChinasFault George...
# ...

# %%
#dropping a column(s)
dropingcolumn=twitterinfo.drop('retweets',axis=1)
dropingcolumn
# Out:
#                 date        username  replies  favorites  \
# 0     7/7/2020 12:40       waswa_jnr        0          4
# 1      7/7/2020 8:36     Sofiesweet1        0          0
# 2      7/7/2020 6:15      akuu_lunya        0          0
# 3      7/7/2020 4:14   locco_veteran        0          0
# 4    6/24/2020 21:49     PastorJeebs        0          0
# ..               ...             ...      ...        ...
# 100   7/27/2013 9:22      wpcommaven        0          0
# 101  5/22/2013 22:34  JanaCernavskis        0          0
# 102  10/17/2012 2:34    activist_hat        0          0
# 103  3/26/2012 23:21      haanapopyk        1          0
# 104   1/17/2012 2:11  teresamccarthy        0          0
#
#                              hashtags  \
# 0      #ItsChinasFault #JoanChallenge
# 1                   # #itschinasfault
# 2                     #itsChinasfault
# 3                     #itschinasfault
# 4                     #ItsChinasFault
# ..                                ...
# ...

# %%
#adding the column
twitterinfo['tweetage'] = 'Kimani'
twitterinfo
# Out:
#                 date        username  replies  retweets  favorites  \
# 0     7/7/2020 12:40       waswa_jnr        0         0          4
# 1      7/7/2020 8:36     Sofiesweet1        0         0          0
# 2      7/7/2020 6:15      akuu_lunya        0         0          0
# 3      7/7/2020 4:14   locco_veteran        0         0          0
# 4    6/24/2020 21:49     PastorJeebs        0         0          0
# ..               ...             ...      ...       ...        ...
# 100   7/27/2013 9:22      wpcommaven        0         0          0
# 101  5/22/2013 22:34  JanaCernavskis        0         0          0
# 102  10/17/2012 2:34    activist_hat        0         0          0
# 103  3/26/2012 23:21      haanapopyk        1         0          0
# 104   1/17/2012 2:11  teresamccarthy        0         0          0
#
#                              hashtags  \
# 0      #ItsChinasFault #JoanChallenge
# 1                   # #itschinasfault
# 2                     #itsChinasfault
# ...

# %%
#filtering data by a certain criteria
relevantdata=twitterinfo[(twitterinfo.retweets>=1)]
relevantdata
# Out:
#                date         username  replies  retweets  favorites  \
# 8   5/26/2020 22:19      MartiniDude        0         1          0
# 15   5/3/2020 16:28      GaryPNabhan       13         1         30
# 16  4/27/2020 22:16       mutalabala        0         1          1
# 21   4/19/2020 4:31       TerryinSci        0         2          6
# 22  4/17/2020 13:40        RoseDru63        0         2          3
# 28  4/14/2020 13:40    mikeybcfc1875        0         2          8
# 33   4/8/2020 15:09    cindievaccaro        4        76         59
# 45  3/22/2020 20:14         ajnatale        0         1          2
# 73  3/15/2020 17:10    johnristick99        0         1          1
# 75  3/14/2020 21:06  OngoingTensions        0         1          1
# 77  3/14/2020 18:44           MINCO8        0         1          1
# 78  3/13/2020 16:57        CHag4life        0         1          2
# 79  3/13/2020 13:19       AuntVerity        0         1          2
# ...

# %%
#filtering by serveral criteria
relevantdata=twitterinfo[(twitterinfo.retweets>=3) | twitterinfo.replies>=1]
relevantdata
# Out:
#                 date         username  replies  retweets  favorites  \
# 5     6/21/2020 0:20      MartiniDude        1         0          0
# 9    5/21/2020 17:28   SirLanceisback        1         0          2
# 15    5/3/2020 16:28      GaryPNabhan       13         1         30
# 17   4/23/2020 15:36      Fitzyleelee        1         0          0
# 33    4/8/2020 15:09    cindievaccaro        4        76         59
# 68    3/18/2020 3:46  DontMockMyTypos        2         0          0
# 76   3/14/2020 21:05  OngoingTensions        1         0          0
# 80    3/13/2020 2:56  CrashMaster6000        1         1          3
# 82   3/12/2020 17:44      Matt_Estes_        1         1          5
# 103  3/26/2012 23:21       haanapopyk        1         0          0
#
#                                               hashtags  \
# 5    #ItsTheMediasFault #ItsChinasFault #ItsObamasF...
# 9                                      #ItsChinasfault
# ...

# %%
#Adding a column according to a certain criteria
twitterinfo['popularity']= twitterinfo.retweets.apply(lambda x: 'popular' if x>=1 else 'unpopular')
twitterinfo[0:50]
# Out:
#                date         username  replies  retweets  favorites  \
# 0    7/7/2020 12:40        waswa_jnr        0         0          4
# 1     7/7/2020 8:36      Sofiesweet1        0         0          0
# 2     7/7/2020 6:15       akuu_lunya        0         0          0
# 3     7/7/2020 4:14    locco_veteran        0         0          0
# 4   6/24/2020 21:49      PastorJeebs        0         0          0
# 5    6/21/2020 0:20      MartiniDude        1         0          0
# 6    6/12/2020 3:30   NOSLEEPATALL69        0         0          0
# 7   5/28/2020 20:47   SirLanceisback        0         0          3
# 8   5/26/2020 22:19      MartiniDude        0         1          0
# 9   5/21/2020 17:28   SirLanceisback        1         0          2
# 10  5/21/2020 15:49   SirLanceisback        0         0          2
# 11   5/21/2020 2:27  Blondiemcblond1        0         0          0
# 12   5/20/2020 3:30   TheDailyPoint1        0         0          0
# ...

# %%
#this adds a column that uses a criteria if a post is popular or not
populardata = twitterinfo[(twitterinfo.popularity == 'popular')]
populardata
# Out:
#                date         username  replies  retweets  favorites  \
# 8   5/26/2020 22:19      MartiniDude        0         1          0
# 15   5/3/2020 16:28      GaryPNabhan       13         1         30
# 16  4/27/2020 22:16       mutalabala        0         1          1
# 21   4/19/2020 4:31       TerryinSci        0         2          6
# 22  4/17/2020 13:40        RoseDru63        0         2          3
# 28  4/14/2020 13:40    mikeybcfc1875        0         2          8
# 33   4/8/2020 15:09    cindievaccaro        4        76         59
# 45  3/22/2020 20:14         ajnatale        0         1          2
# 73  3/15/2020 17:10    johnristick99        0         1          1
# 75  3/14/2020 21:06  OngoingTensions        0         1          1
# 77  3/14/2020 18:44           MINCO8        0         1          1
# 78  3/13/2020 16:57        CHag4life        0         1          2
# 79  3/13/2020 13:19       AuntVerity        0         1          2
# ...

# %%
#to count how many popular tweets and how many are not popular
twitterinfo.popularity.value_counts()
# Out:
# unpopular    81
# popular      24
# Name: popularity, dtype: int64

# %%
twitterinfo['text']
# Out:
# 0      "Mashakos" Mutahi Kagwe #ItsChinasFault George...
# 1      M.S corona has ruined many peoples lives all b...
# 2      China treats us abnormally just because our ge...
# 3      Everything fake, situation faking see what we ...
# 4                                        #ItsChinasFault
#                              ...
# 100    Latest theory as to why @wordpressdotcom is be...
# 101    The past 24 hours I hold in both the highest a...
# 102    China will be waging a war with us soon thanks...
# 103    @ajhubs @christaaaygraff Tell me about it .. #...
# 104    R-Money, demands more time to answer, before h...
# Name: text, Length: 105, dtype: object

# %%
twitterinfo.drop('tweetage',axis=1)
twitterinfo.drop('popular',axis=1)
# Out:
#                 date        username  replies  retweets  favorites  \
# 0     7/7/2020 12:40       waswa_jnr        0         0          4
# 1      7/7/2020 8:36     Sofiesweet1        0         0          0
# 2      7/7/2020 6:15      akuu_lunya        0         0          0
# 3      7/7/2020 4:14   locco_veteran        0         0          0
# 4    6/24/2020 21:49     PastorJeebs        0         0          0
# ..               ...             ...      ...       ...        ...
# 100   7/27/2013 9:22      wpcommaven        0         0          0
# 101  5/22/2013 22:34  JanaCernavskis        0         0          0
# 102  10/17/2012 2:34    activist_hat        0         0          0
# 103  3/26/2012 23:21      haanapopyk        1         0          0
# 104   1/17/2012 2:11  teresamccarthy        0         0          0
#
#                              hashtags  \
# 0      #ItsChinasFault #JoanChallenge
# 1                   # #itschinasfault
# 2                     #itsChinasfault
# ...

# %%
twitterinfo.drop('tweetage',axis=1)
# Out:
#                 date        username  replies  retweets  favorites  \
# 0     7/7/2020 12:40       waswa_jnr        0         0          4
# 1      7/7/2020 8:36     Sofiesweet1        0         0          0
# 2      7/7/2020 6:15      akuu_lunya        0         0          0
# 3      7/7/2020 4:14   locco_veteran        0         0          0
# 4    6/24/2020 21:49     PastorJeebs        0         0          0
# ..               ...             ...      ...       ...        ...
# 100   7/27/2013 9:22      wpcommaven        0         0          0
# 101  5/22/2013 22:34  JanaCernavskis        0         0          0
# 102  10/17/2012 2:34    activist_hat        0         0          0
# 103  3/26/2012 23:21      haanapopyk        1         0          0
# 104   1/17/2012 2:11  teresamccarthy        0         0          0
#
#                              hashtags  \
# 0      #ItsChinasFault #JoanChallenge
# 1                   # #itschinasfault
# 2                     #itsChinasfault
# ...

# %%
#adding dummies to values to check popularlity in a binary method
dummy_values= pd.get_dummies(twitterinfo[['popularity']])
dummy_values
# Out:
#      popularity_popular  popularity_unpopular
# 0                     0                     1
# 1                     0                     1
# 2                     0                     1
# 3                     0                     1
# 4                     0                     1
# ..                  ...                   ...
# 100                   0                     1
# 101                   0                     1
# 102                   0                     1
# 103                   0                     1
# 104                   0                     1
#
# [105 rows x 2 columns]

# %%
twitterinfo
# Out:
#                 date        username  replies  retweets  favorites  \
# 0     7/7/2020 12:40       waswa_jnr        0         0          4
# 1      7/7/2020 8:36     Sofiesweet1        0         0          0
# 2      7/7/2020 6:15      akuu_lunya        0         0          0
# 3      7/7/2020 4:14   locco_veteran        0         0          0
# 4    6/24/2020 21:49     PastorJeebs        0         0          0
# ..               ...             ...      ...       ...        ...
# 100   7/27/2013 9:22      wpcommaven        0         0          0
# 101  5/22/2013 22:34  JanaCernavskis        0         0          0
# 102  10/17/2012 2:34    activist_hat        0         0          0
# 103  3/26/2012 23:21      haanapopyk        1         0          0
# 104   1/17/2012 2:11  teresamccarthy        0         0          0
#
#                              hashtags  \
# 0      #ItsChinasFault #JoanChallenge
# 1                   # #itschinasfault
# 2                     #itsChinasfault
# ...

# %%
#to save analyzed data in a csv file
relevantdata.to_csv('analyzed.csv')
